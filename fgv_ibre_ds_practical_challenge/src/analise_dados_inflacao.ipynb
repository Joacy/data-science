# %% [markdown]
# # Contexto dos Índices

# %% [markdown]
# ### IPCA
#
# O Índice Nacional de Preços ao Consumidor Amplo - IPCA, tem por objetivo medir a inflação de um conjunto de produtos e serviços comercializados no varejo, referentes ao consumo pessoal das famílias. Esta faixa de renda foi criada com o objetivo de garantir uma cobertura de 90% das famílias pertencentes às áreas urbanas de cobertura do Sistema Nacional de Índices de Preços ao Consumidor - SNIPC.
#
# Atualmente, a população-objetivo do IPCA abrange as famílias com rendimentos de 1 a 40 salários mínimos, qualquer que seja a fonte, residentes nas áreas urbanas das regiões de abrangência do SNIPC, as quais são: regiões metropolitanas de Belém, Fortaleza, Recife, Salvador, Belo Horizonte, Vitória, Rio de Janeiro, São Paulo, Curitiba, Porto Alegre, além do Distrito Federal e dos municípios de Goiânia, Campo Grande, Rio Branco, São Luís e Aracaju.
#
# Para chegar ao índice de inflação, são coletados os preços durante cada mês em lojas e estabelecimentos de prestação de serviços, concessionárias de serviços públicos (como água ou energia elétrica), além da internet.
#
# O IPCA é o índice oficial de inflação do Brasil.
#
# Referência: https://www.ibge.gov.br/estatisticas/economicas/precos-e-custos/9256-indice-nacional-de-precos-ao-consumidor-amplo.html?t=o-que-e
#
# ### IGP-M
#
# O Índice Geral de Preços - IGP, é a média aritmética ponderada de três índices de preços: IPA, IPC e INCC, e revela as fontes de pressão inflacionária e a evolução dos preços de produtos e serviços mais relevantes para produtor, consumidor e construção civil.
#
# O IGP foi concebido no final dos anos de 1940 para ser uma medida abrangente do movimento de preços no país. Entendia-se por abrangente um índice que englobasse não apenas diferentes atividades como também etapas distintas do processo produtivo. Construído dessa forma, o IGP poderia ser usado como deflator do índice de evolução dos negócios, daí resultando um indicador mensal do nível de atividade econômica. Os pesos de cada um dos índices componentes correspondem a parcelas da despesa interna bruta, calculadas com base nas Contas Nacionais.
#
# A composição do IGP é a seguinte: 60% Índice de Preços ao Produtor Amplo (IPA), 30% Índice de Preços ao Consumidor (IPC), 10% Índice Nacional de Custo da Construção (INCC).
#
# Os setores pesquisados para o cálculo do IGP são os de alimentação, habitação, vestuário, saúde e cuidados pessoais, educação, leitura e recreação, transportes, despesas diversas e comunicação, sob o ponto de vista do produtor e do consumidor. Além de materiais e equipamentos, serviços e mão-de-obra.
#
# O IGP–M é pesquisado entre os dias 21 do mês anterior e 20 do mês de referência
#
# Referência: https://portalibre.fgv.br/igp
#
# ### IPC-BR-M
#
# O Índice de Preços ao Consumidor (IPC) mede a variação de preços de um conjunto fixo de bens e serviços componentes de despesas habituais de famílias com nível de renda situado entre 1 e 33 salários mínimos mensais. Sua pesquisa de preços se desenvolve diariamente, cobrindo sete das principais capitais do país: São Paulo, Rio de Janeiro, Belo Horizonte, Salvador, Recife, Porto Alegre e Brasília.
#
# O cálculo do IPC é realizado com base nas despesas de consumo obtidas através da Pesquisa de Orçamentos Familiares (POF) realizada no biênio (2008/2009) pelo IBGE. Com as informações do levantamento foram construídas as estruturas de ponderação que expressam, em termos percentuais, a importância monetária dos bens e serviços componentes da amostra do IPC.
#
# Com base na POF construiu-se a composição final das versões do Índice de Preços ao Consumidor. Os bens e serviços que integram a amostra foram classificados em oito grupos ou classes de despesa, 25 subgrupos, 85 itens e 338 subitens.
#
# As oito classes de despesa são: Alimentação, Habitação, Vestuário, Saúde e Cuidados Pessoais, Educação, Leitura e Recreação, Transportes, Despesas Diversas e Comunicação.
#
# Referência: https://portalibre.fgv.br/estudos-e-pesquisas/indices-de-precos/ipc
#
# ### IPA-EP-M
#
# O Índice de Preços ao Produtor Amplo - IPA registra variações de preços de produtos agropecuários e industriais nas transações interempresariais, isto é, nos estágios de comercialização anteriores ao consumo final.
#
# Em 1964, quando foi introduzida a correção monetária no Brasil, o IPA foi escolhido como índice de referência para correção das Obrigações Reajustáveis do Tesouro Nacional (ORTN). Posteriormente o IPA começou a ser utilizado também em outras operações como, por exemplo, no cálculo da Unidade Padrão de Capital (UPC), parâmetro de reajuste de financiamentos imobiliários.
#
# A pesquisa de preços em que se baseia o cálculo do IPA é realizada continuamente, sendo feitas apurações a cada decêndio (espaço de 10 dias). O IPA está disponível nas mesmas versões do IGP (IPA-10, IPA-M e IPA-DI), que têm em comum a amostra de produtos e o cálculo, diferindo apenas no período de coleta de preços.
#
# Referência: https://portalibre.fgv.br/estudos-e-pesquisas/indices-de-precos/ipa
#
# ### INCC-M
#
# O Índice Nacional de Custo da Construção (INCC) foi o primeiro índice desenvolvido para monitorar a evolução dos preços de materiais, serviços e mão-de-obra destinados a construção de residências no Brasil. Além de se um dos índices componentes do Índice Geral de Preços (IGP) do FGV IBRE, o INCC continua sendo, mais de 70 anos depois, um dos mais importantes indicadores de preços para o seu segmento.
#
# Na década de 50, sua abrangência era limitada à cidade do Rio de Janeiro . Nas décadas seguintes, passou a ser calculado com base na evolução do custo da construção em sete das principais capitais brasileiras: Belo Horizonte, Brasília, Porto Alegre, Recife, Rio de Janeiro, São Paulo e Salvador.
#
# Referência: https://portalibre.fgv.br/incc

# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
from dateutil import parser
import matplotlib.pyplot as plt

# %% [markdown]
# # Pré-Processamento dos dados

# %% [markdown]
# Importando a planilha com os índices

# %%
indices_df = pd.read_excel("../data/indices.xls")

# %% [markdown]
# Dicionário com o número presente na planilha e os índices referentes

# %%
indices_dict = {
    '1': "IPCA",
    '2': "IGP-M",
    '3': "IPC-BR-M",
    '4': "IPA-EP-M",
    '5': "INCC-M"
}

# %% [markdown]
# Coletando apenas os índices, retirando o cabeçalho com as informações sobre cada um deles

# %%
indices_df = indices_df[16:-1]
indices_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 16       Data          1          2          3          4          5
# 17    12/1993        100    7.97925         -          -          -
# 18    01/1994     141.31    11.0968         -          -          -
# 19    02/1994     198.22    15.6219         -          -          -
# 20    03/1994     282.96    22.7628         -          -          -
#
#    Unnamed: 6
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN

# %% [markdown]
# Mantendo apenas as 5 colunas com os valores dos índices, e renomeando as colunas

# %%
indices_df = indices_df[["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3", "Unnamed: 4", "Unnamed: 5"]]
columns = indices_df.iloc[0].tolist()
indices_df.columns = columns
indices_df = indices_df.iloc[1:-1]
indices_df.head()
# Out:
#        Data       1        2    3    4    5
# 17  12/1993     100  7.97925   -    -    -
# 18  01/1994  141.31  11.0968   -    -    -
# 19  02/1994  198.22  15.6219   -    -    -
# 20  03/1994  282.96  22.7628   -    -    -
# 21  04/1994  403.73  32.0749   -    -    -

# %% [markdown]
# Resetando os índices das linhas do dataframe

# %%
indices_df = indices_df.reset_index()
indices_df = indices_df[['Data', '1', '2', '3', '4', '5']]
indices_df.head()
# Out:
#       Data       1        2    3    4    5
# 0  12/1993     100  7.97925   -    -    -
# 1  01/1994  141.31  11.0968   -    -    -
# 2  02/1994  198.22  15.6219   -    -    -
# 3  03/1994  282.96  22.7628   -    -    -
# 4  04/1994  403.73  32.0749   -    -    -

# %% [markdown]
# Convertendo as datas para datetime

# %%
datas = []
for data in indices_df["Data"]:
    date_time = parser.parse(data)
    datas.append(date_time)

indices_df["Data"] = datas
indices_df.head()
# Out:
#         Data       1        2    3    4    5
# 0 1993-12-03     100  7.97925   -    -    -
# 1 1994-01-03  141.31  11.0968   -    -    -
# 2 1994-02-03  198.22  15.6219   -    -    -
# 3 1994-03-03  282.96  22.7628   -    -    -
# 4 1994-04-03  403.73  32.0749   -    -    -

# %% [markdown]
# Substituindo os valores faltantes por NaN

# %%
indices_df = indices_df.replace([" - "], [np.nan])
indices_df.head()
# Out:
#         Data       1         2   3   4   5
# 0 1993-12-03  100.00   7.97925 NaN NaN NaN
# 1 1994-01-03  141.31  11.09680 NaN NaN NaN
# 2 1994-02-03  198.22  15.62190 NaN NaN NaN
# 3 1994-03-03  282.96  22.76280 NaN NaN NaN
# 4 1994-04-03  403.73  32.07490 NaN NaN NaN

# %% [markdown]
# Filtrando o período para a partir de Janeiro de 1995

# %%
jan_95 = (indices_df['Data'].dt.year >= 1995)
indices_df_Jan1995_Jun2022 = indices_df[jan_95]
indices_df_Jan1995_Jun2022
# Out:
#           Data        1         2        3         4        5
# 13  1995-01-03  1033.74   108.442      NaN   107.599  106.581
# 14  1995-02-03  1044.28   109.945      NaN   108.542  110.354
# 15  1995-03-03  1060.47   111.178      NaN   108.673  113.014
# 16  1995-04-03  1086.24   113.518      NaN   110.428  116.114
# 17  1995-05-03  1115.24   114.171      NaN   109.627  118.936
# ..         ...      ...       ...      ...       ...      ...
# 336 2021-12-03  6120.04  1100.988  664.319  1342.671  960.894
# 337 2022-01-03  6153.09  1120.999  667.131  1373.599  967.003
# 338 2022-02-03  6215.24  1141.546  669.332  1405.969  971.651
# 339 2022-03-03  6315.93  1161.418  675.117  1435.019  978.717
# 340 2022-04-03  6382.88  1177.809  685.432  1455.762  987.218
#
# [328 rows x 6 columns]

# %% [markdown]
# Resetando os índices do dataframe e renomeando as colunas

# %%
indices_df_Jan1995_Jun2022 = indices_df_Jan1995_Jun2022.reset_index()
indices_df_Jan1995_Jun2022 = indices_df_Jan1995_Jun2022[['Data', '1', '2', '3', '4', '5']]
indices_df_Jan1995_Jun2022.columns = [["Data", indices_dict['1'], indices_dict['2'], indices_dict['3'], indices_dict['4'], indices_dict['5']]]
indices_df_Jan1995_Jun2022
# Out:
#           Data     IPCA     IGP-M IPC-BR-M  IPA-EP-M   INCC-M
# 0   1995-01-03  1033.74   108.442      NaN   107.599  106.581
# 1   1995-02-03  1044.28   109.945      NaN   108.542  110.354
# 2   1995-03-03  1060.47   111.178      NaN   108.673  113.014
# 3   1995-04-03  1086.24   113.518      NaN   110.428  116.114
# 4   1995-05-03  1115.24   114.171      NaN   109.627  118.936
# ..         ...      ...       ...      ...       ...      ...
# 323 2021-12-03  6120.04  1100.988  664.319  1342.671  960.894
# 324 2022-01-03  6153.09  1120.999  667.131  1373.599  967.003
# 325 2022-02-03  6215.24  1141.546  669.332  1405.969  971.651
# 326 2022-03-03  6315.93  1161.418  675.117  1435.019  978.717
# 327 2022-04-03  6382.88  1177.809  685.432  1455.762  987.218
#
# [328 rows x 6 columns]

# %% [markdown]
# Adicionando colunas com a variação percentual de cada índice

# %%
ipca_percent = []
igpm_percent = []
ipc_percent = []
ipa_percent = []
incc_percent = []

for i in range(len(indices_df_Jan1995_Jun2022)):
    if i == 0:
        ipca_percent.append(indices_df_Jan1995_Jun2022['IPCA'].iloc[i][0] / indices_df_Jan1995_Jun2022['IPCA'].iloc[i][0])
        igpm_percent.append(indices_df_Jan1995_Jun2022['IGP-M'].iloc[i][0] / indices_df_Jan1995_Jun2022['IGP-M'].iloc[i][0])
        ipc_percent.append(indices_df_Jan1995_Jun2022['IPC-BR-M'].iloc[i][0] / indices_df_Jan1995_Jun2022['IPC-BR-M'].iloc[i][0])
        ipa_percent.append(indices_df_Jan1995_Jun2022['IPA-EP-M'].iloc[i][0] / indices_df_Jan1995_Jun2022['IPA-EP-M'].iloc[i][0])
        incc_percent.append(indices_df_Jan1995_Jun2022['INCC-M'].iloc[i][0] / indices_df_Jan1995_Jun2022['INCC-M'].iloc[i][0])
    
    ipca_percent.append((indices_df_Jan1995_Jun2022['IPCA'].iloc[i][0] - indices_df_Jan1995_Jun2022['IPCA'].iloc[i - 1][0]) / (indices_df_Jan1995_Jun2022['IPCA'].iloc[i - 1][0]) * 100)
    igpm_percent.append((indices_df_Jan1995_Jun2022['IGP-M'].iloc[i][0] - indices_df_Jan1995_Jun2022['IGP-M'].iloc[i - 1][0]) / (indices_df_Jan1995_Jun2022['IGP-M'].iloc[i - 1][0]) * 100)
    ipc_percent.append((indices_df_Jan1995_Jun2022['IPC-BR-M'].iloc[i][0] - indices_df_Jan1995_Jun2022['IPC-BR-M'].iloc[i - 1][0]) / (indices_df_Jan1995_Jun2022['IPC-BR-M'].iloc[i - 1][0]) * 100)
    ipa_percent.append((indices_df_Jan1995_Jun2022['IPA-EP-M'].iloc[i][0] - indices_df_Jan1995_Jun2022['IPA-EP-M'].iloc[i - 1][0]) / (indices_df_Jan1995_Jun2022['IPA-EP-M'].iloc[i - 1][0]) * 100)
    incc_percent.append((indices_df_Jan1995_Jun2022['INCC-M'].iloc[i][0] - indices_df_Jan1995_Jun2022['INCC-M'].iloc[i - 1][0]) / (indices_df_Jan1995_Jun2022['INCC-M'].iloc[i - 1][0]) * 100)

ipca_percent.pop(1)
igpm_percent.pop(1)
ipc_percent.pop(1)
ipa_percent.pop(1)
incc_percent.pop(1)

indices_df_Jan1995_Jun2022['ipca_percent'] = ipca_percent
indices_df_Jan1995_Jun2022['igpm_percent'] = igpm_percent
indices_df_Jan1995_Jun2022['ipc_percent'] = ipc_percent
indices_df_Jan1995_Jun2022['ipa_percent'] = ipa_percent
indices_df_Jan1995_Jun2022['incc_percent'] = incc_percent

indices_df_Jan1995_Jun2022.head()
# Out:
#         Data     IPCA    IGP-M IPC-BR-M IPA-EP-M   INCC-M ipca_percent  \
# 0 1995-01-03  1033.74  108.442      NaN  107.599  106.581     1.000000
# 1 1995-02-03  1044.28  109.945      NaN  108.542  110.354     1.019599
# 2 1995-03-03  1060.47  111.178      NaN  108.673  113.014     1.550350
# 3 1995-04-03  1086.24  113.518      NaN  110.428  116.114     2.430055
# 4 1995-05-03  1115.24  114.171      NaN  109.627  118.936     2.669760
#
#   igpm_percent ipc_percent ipa_percent incc_percent
# 0     1.000000         NaN    1.000000     1.000000
# 1     1.385994         NaN    0.876402     3.540031
# 2     1.121470         NaN    0.120691     2.410425
# 3     2.104733         NaN    1.614937     2.743023
# 4     0.575239         NaN   -0.725360     2.430370

# %% [markdown]
# # Análise Exploratória dos dados

# %% [markdown]
# ## IPCA

# %% [markdown]
# ### Como se apresenta o IPCA ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['IPCA'])
plt.title('IPCA ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('IPCA')
plt.show()

# %% [markdown]
# ### Como se apresenta a variação percentual do IPCA ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['ipca_percent'])
plt.title('Variação percentual do IPCA ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Variação do IPCA')
plt.show()

# %% [markdown]
# ### Como se comporta a variação percentual do IPCA ao longo dos meses (estatisticamente)?

# %%
display("Média das variações")
display(indices_df_Jan1995_Jun2022['ipca_percent'].mean()[0])

display("Desvio padrão das variações")
display(indices_df_Jan1995_Jun2022['ipca_percent'].std()[0])

display("Mediana das variações")
display(indices_df_Jan1995_Jun2022['ipca_percent'].median()[0])
# Out:
# 'Média das variações'
# 0.5606654704735868
# 'Desvio padrão das variações'
# 0.4637768946463603
# 'Mediana das variações'
# 0.47017239585666426

# %% [markdown]
# ## IGP-M

# %% [markdown]
# ### Como se apresenta o IGP-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['IGP-M'])
plt.title('IGP-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('IGP-M')
plt.show()

# %% [markdown]
# ### Como se apresenta a variação percentual do IGP-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['igpm_percent'])
plt.title('Variação percentual do IGP-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Variação do IGP-M')
plt.show()

# %% [markdown]
# ### Como se comporta a variação percentual do IGP-M ao longo dos meses (estatisticamente)?

# %%
display("Média das variações")
display(indices_df_Jan1995_Jun2022['igpm_percent'].mean()[0])

display("Desvio padrão das variações")
display(indices_df_Jan1995_Jun2022['igpm_percent'].std()[0])

display("Mediana das variações")
display(indices_df_Jan1995_Jun2022['igpm_percent'].median()[0])
# Out:
# 'Média das variações'
# 0.7367388600512775
# 'Desvio padrão das variações'
# 0.884194934636859
# 'Mediana das variações'
# 0.6213882444742684

# %% [markdown]
# ## IPC-BR-M

# %% [markdown]
# ### Como se apresenta o IPC-BR-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['IPC-BR-M'])
plt.title('IPC-BR-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('IPC-BR-M')
plt.show()

# %% [markdown]
# ### Como se apresenta a variação percentual do IPC-BR-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['ipc_percent'])
plt.title('Variação percentual do IPC-BR-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Variação do IPC-BR-M')
plt.show()

# %% [markdown]
# ### Como se comporta a variação percentual do IPC-BR-M ao longo dos meses (estatisticamente)?

# %%
display("Média das variações")
display(indices_df_Jan1995_Jun2022['ipc_percent'].mean()[0])

display("Desvio padrão das variações")
display(indices_df_Jan1995_Jun2022['ipc_percent'].std()[0])

display("Mediana das variações")
display(indices_df_Jan1995_Jun2022['ipc_percent'].median()[0])
# Out:
# 'Média das variações'
# 0.49492344254343634
# 'Desvio padrão das variações'
# 0.4319775611004145
# 'Mediana das variações'
# 0.42647836044394727

# %% [markdown]
# ## IPA-EP-M

# %% [markdown]
# ### Como se apresenta o IPA-EP-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['IPA-EP-M'])
plt.title('IPA-EP-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('IPA-EP-M')
plt.show()

# %% [markdown]
# ### Como se apresenta a variação percentual do IPA-EP-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['ipa_percent'])
plt.title('Variação percentual do IPA-EP-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('IPA-EP-M')
plt.show()

# %% [markdown]
# ### Como se comporta a variação percentual do IPA-EP-M ao longo dos meses (estatisticamente)?

# %%
display("Média das variações")
display(indices_df_Jan1995_Jun2022['ipa_percent'].mean()[0])

display("Desvio padrão das variações")
display(indices_df_Jan1995_Jun2022['ipa_percent'].std()[0])

display("Mediana das variações")
display(indices_df_Jan1995_Jun2022['ipa_percent'].median()[0])
# Out:
# 'Média das variações'
# 0.8078563770271988
# 'Desvio padrão das variações'
# 1.2355194033888022
# 'Mediana das variações'
# 0.6351835727795735

# %% [markdown]
# ## INCC-M

# %% [markdown]
# ### Como se apresenta o INCC-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['INCC-M'])
plt.title('INCC-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('INCC-M')
plt.show()

# %% [markdown]
# ### Como se apresenta a variação percentual do INCC-M ao longo do período?

# %%
plt.figure(figsize=(7,5))
plt.plot(indices_df_Jan1995_Jun2022['Data'], indices_df_Jan1995_Jun2022['incc_percent'])
plt.title('Variação percentual do INCC-M ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Variação do INCC-M')
plt.show()

# %% [markdown]
# ### Como se comporta a variação percentual do INCC-M ao longo dos meses (estatisticamente)?

# %%
display("Média das variações")
display(indices_df_Jan1995_Jun2022['incc_percent'].mean()[0])

display("Desvio padrão das variações")
display(indices_df_Jan1995_Jun2022['incc_percent'].std()[0])

display("Mediana das variações")
display(indices_df_Jan1995_Jun2022['incc_percent'].median()[0])
# Out:
# 'Média das variações'
# 0.6867319395196634
# 'Desvio padrão das variações'
# 0.7503727695055362
# 'Mediana das variações'
# 0.48282249365121455

# %% [markdown]
# ## Correlação entre as variações de cada índice com o IPCA

# %% [markdown]
# ### IPCA vs IGP-M

# %%
from sklearn.linear_model import LinearRegression

plt.figure(figsize=(7,5))
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipca_percent'],
            c='b',
            label='IPCA')
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['igpm_percent'],
            c='r', label='IGP-M')
plt.legend(loc='best')
plt.title('Variação IPCA x Variação IGP-M')
plt.ylabel('Variação do Índice')
plt.xlabel('Data')
plt.grid()
plt.show()

ipca_igpm = pd.DataFrame()
ipca_igpm['IPCA'] = indices_df_Jan1995_Jun2022['ipca_percent']
ipca_igpm['IGP-M'] = indices_df_Jan1995_Jun2022['igpm_percent']

ipca_igpm = ipca_igpm.fillna(0)

print('')
display('Coeficiente de correlação de Pearson entre as variações do IPCA e do IGP-M')
display(ipca_igpm.corr(method='pearson'))

X = ipca_igpm['IPCA'].values.reshape(-1, 1)
Y = ipca_igpm['IGP-M'].values.reshape(-1, 1)

reg = LinearRegression().fit(X, Y)
Y_pred = reg.predict(X)

print('')
print('a=', reg.coef_, 'b=', reg.intercept_)

plt.figure(figsize=(7,5))
plt.scatter(x=X, y=Y, c='r')
plt.plot(X, Y_pred, c='b')
plt.grid()
plt.show()
# Out:
# 'Coeficiente de correlação de Pearson entre as variações do IPCA e do IGP-M'
#            IPCA     IGP-M
# IPCA   1.000000  0.562454
# IGP-M  0.562454  1.000000
# a= [[1.07232456]] b= [0.1355235]

# %% [markdown]
# ### IPCA vs IPC-BR-M

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipca_percent'],
            c='b',
            label='IPCA')
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipc_percent'],
            c='r', label='IPC-BR-M')
plt.legend(loc='best')
plt.title('Variação IPCA x Variação IPC-BR-M')
plt.ylabel('Variação do Índice')
plt.xlabel('Data')
plt.grid()
plt.show()

ipca_ipc = pd.DataFrame()
ipca_ipc['IPCA'] = indices_df_Jan1995_Jun2022['ipca_percent']
ipca_ipc['IPC-BR-M'] = indices_df_Jan1995_Jun2022['ipc_percent']

ipca_ipc = ipca_ipc.fillna(0)

print('')
display('Coeficiente de correlação de Pearson entre as variações do IPCA e do IPC-BR-M')
display(ipca_ipc.corr(method='pearson'))

X = ipca_ipc['IPCA'].values.reshape(-1, 1)
Y = ipca_ipc['IPC-BR-M'].values.reshape(-1, 1)

reg = LinearRegression().fit(X, Y)
Y_pred = reg.predict(X)

print('')
print('a=', reg.coef_, 'b=', reg.intercept_)

plt.figure(figsize=(7,5))
plt.scatter(x=X, y=Y, c='r')
plt.plot(X, Y_pred, c='b')
plt.grid()
plt.show()
# Out:
# 'Coeficiente de correlação de Pearson entre as variações do IPCA e do IPC-BR-M'
#               IPCA  IPC-BR-M
# IPCA      1.000000  0.583344
# IPC-BR-M  0.583344  1.000000
# a= [[0.54679026]] b= [0.1627055]

# %% [markdown]
# ### IPCA vs IPA-EP-M

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipca_percent'],
            c='b',
            label='IPCA')
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipa_percent'],
            c='r', label='IPA-EP-M')
plt.legend(loc='best')
plt.title('Variação IPCA x Variação IPA-EP-M')
plt.ylabel('Variação do Índice')
plt.xlabel('Data')
plt.grid()
plt.show()

ipca_ipa = pd.DataFrame()
ipca_ipa['IPCA'] = indices_df_Jan1995_Jun2022['ipca_percent']
ipca_ipa['IPA-EP-M'] = indices_df_Jan1995_Jun2022['ipa_percent']

ipca_ipa = ipca_ipa.fillna(0)

print('')
display('Coeficiente de correlação de Pearson entre as variações do IPCA e do IPA-EP-M')
display(ipca_ipa.corr(method='pearson'))

X = ipca_ipa['IPCA'].values.reshape(-1, 1)
Y = ipca_ipa['IPA-EP-M'].values.reshape(-1, 1)

reg = LinearRegression().fit(X, Y)
Y_pred = reg.predict(X)

print('')
print('a=', reg.coef_, 'b=', reg.intercept_)

plt.figure(figsize=(7,5))
plt.scatter(x=X, y=Y, c='r')
plt.plot(X, Y_pred, c='b')
plt.grid()
plt.show()
# Out:
# 'Coeficiente de correlação de Pearson entre as variações do IPCA e do IPA-EP-M'
#               IPCA  IPA-EP-M
# IPCA      1.000000  0.420205
# IPA-EP-M  0.420205  1.000000
# a= [[1.11944149]] b= [0.18022419]

# %% [markdown]
# ### IPCA vs INCC-M

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['ipca_percent'],
            c='b',
            label='IPCA')
plt.scatter(x=indices_df_Jan1995_Jun2022['Data'],
            y=indices_df_Jan1995_Jun2022['incc_percent'],
            c='r', label='INCC-M')
plt.legend(loc='best')
plt.title('Variação IPCA x Variação INCC-M')
plt.ylabel('Variação do Índice')
plt.xlabel('Data')
plt.grid()
plt.show()

ipca_incc = pd.DataFrame()
ipca_incc['IPCA'] = indices_df_Jan1995_Jun2022['ipca_percent']
ipca_incc['INCC-M'] = indices_df_Jan1995_Jun2022['incc_percent']

ipca_incc = ipca_incc.fillna(0)

print('')
display('Coeficiente de correlação de Pearson entre as variações do IPCA e do INCC-M')
display(ipca_incc.corr(method='pearson'))

X = ipca_incc['IPCA'].values.reshape(-1, 1)
Y = ipca_incc['INCC-M'].values.reshape(-1, 1)

reg = LinearRegression().fit(X, Y)
Y_pred = reg.predict(X)

print('')
print('a=', reg.coef_, 'b=', reg.intercept_)

plt.figure(figsize=(7,5))
plt.scatter(x=X, y=Y, c='r')
plt.plot(X, Y_pred, c='b')
plt.grid()
plt.show()
# Out:
# 'Coeficiente de correlação de Pearson entre as variações do IPCA e do INCC-M'
#             IPCA    INCC-M
# IPCA    1.000000  0.416458
# INCC-M  0.416458  1.000000
# a= [[0.67381271]] b= [0.30894842]

# %% [markdown]
# ### Análise da Correlação

# %% [markdown]
# Em relação a todos os índices, os coeficientes de correlação indicam uma correlação positiva entre a variação do IPCA e a variação de cada índice. Sendo que o IPC-BR-M e o IGP-M apresentaram os maiores valores de coeficiente, indicando que a variação desses índices possuem maior relação com a variação do IPCA.

# %% [markdown]
# Para o modelo de predição do IPCA, antes precisaremos estimar a variação dos demais índices nos próximos 06 meses. Posteriormente, um modelo de regressão linear será treinado tendo como saída o IPCA, e como entrada os outros índices.
